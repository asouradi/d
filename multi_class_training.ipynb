# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
import os
# %matplotlib inline


config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# define the base path to the input dataset and then use it to derive
# the path to the input images and annotation CSV files
BASE_PATH = "dataset2"
IMAGES_PATH = os.path.sep.join([BASE_PATH, "images"])
ANNOTS_PATH = os.path.sep.join([BASE_PATH, "annotations"])

# %% [markdown]
# initialize the list of data (images), class labels, target bounding box coordinates, and image paths

# %%
data = []
labels = []
bboxes = []
imagePaths = []

# %%
csvPaths = []
for (rootDir, dirNames, filenames) in os.walk(ANNOTS_PATH):
    # loop over the filenames in the current directory
    for filename in filenames:
        # determine the file extension of the current file
        ext = filename[filename.rfind("."):].lower()

        # check to see if the file is an image and should be processed
        if ext.endswith(".csv"):
            # construct the path to the image and yield it
            csvPath = os.path.join(rootDir, filename)
            csvPaths.append(csvPath)

csvPaths
# Out:
# ['dataset2\\annotations\\1.csv',
#  'dataset2\\annotations\\2.csv',
#  'dataset2\\annotations\\ram.csv']

# %%
# loop over all CSV files in the annotations directory
for csvPath in csvPaths:
    # load the contents of the current CSV annotations file
    rows = open(csvPath).read().strip().split("\n")

    # loop over the rows
    for row in rows:
        # break the row into the filename, bounding box coordinates,
        # and class label
        row = row.split(",")
        (filename, startX, startY, endX, endY, label) = row

        # derive the path to the input image, load the image (in
        # OpenCV format), and grab its dimensions
        imagePath = os.path.sep.join([IMAGES_PATH, label, filename])
        image = cv2.imread(imagePath)
        (h, w) = image.shape[:2]

        # scale the bounding box coordinates relative to the spatial
        # dimensions of the input image
        startX = float(startX) / w
        startY = float(startY) / h
        endX = float(endX) / w
        endY = float(endY) / h

        # load the image and preprocess it
        image = load_img(imagePath, target_size=(224, 224))
        image = img_to_array(image)

        # update our list of data, class labels, bounding boxes, and
        # image paths
        data.append(image)
        labels.append(label)
        bboxes.append((startX, startY, endX, endY))
        imagePaths.append(imagePath)

# %%
# convert the data, class labels, bounding boxes, and image paths to
# NumPy arrays, scaling the input pixel intensities from the range
# [0, 255] to [0, 1]
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
bboxes = np.array(bboxes, dtype="float32")
imagePaths = np.array(imagePaths)

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
split = train_test_split(data, labels, bboxes, imagePaths, test_size=0.20, random_state=42)
# unpack the data split
(trainImages, testImages) = split[:2]
(trainLabels, testLabels) = split[2:4]
(trainBBoxes, testBBoxes) = split[4:6]
(trainPaths, testPaths) = split[6:]

# %%
# load the VGG16 network, ensuring the head FC layers are left off
vgg = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# %%
# freeze all VGG layers so they will *not* be updated during the
# training process
vgg.trainable = False

# %%
# flatten the max-pooling output of VGG
flatten = vgg.output
flatten = Flatten()(flatten)

# construct a fully-connected layer header to output the predicted
# bounding box coordinates
bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid", name="bounding_box")(bboxHead)

# construct a second fully-connected layer head, this one to predict
# the class label
softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(len(lb.classes_), activation="softmax", name="class_label")(softmaxHead)

# put together our model which accept an input image and then output
# bounding box coordinates and a class label
model = Model(inputs=vgg.input, outputs=(bboxHead, softmaxHead))

# %%
# define a dictionary to set the loss methods -- categorical
# cross-entropy for the class label head and mean absolute error
# for the bounding box head
losses = {
    "class_label": "categorical_crossentropy",
    "bounding_box": "mean_squared_error",
}

# define a dictionary that specifies the weights per loss (both the
# class label and bounding box outputs will receive equal weight)
lossWeights = {
    "class_label": 1.0,
    "bounding_box": 1.0
}

# %%
# initialize the optimizer, compile the model, and show the model
# summary
opt = Adam(lr=1e-4)
model.compile(loss=losses, optimizer=opt, metrics=["accuracy"], loss_weights=lossWeights)

# %%
# construct a dictionary for our target training outputs
trainTargets = {
    "class_label": trainLabels,
    "bounding_box": trainBBoxes
}

# construct a second dictionary, this one for our target testing
# outputs
testTargets = {
    "class_label": testLabels,
    "bounding_box": testBBoxes
}

# train the network for bounding box regression and class label
# prediction
H = model.fit(
    trainImages, trainTargets,
    validation_data=(testImages, testTargets),
    batch_size=8,
    epochs=50,
    verbose=1)
# Out:
# Epoch 1/50
# 2/4 [==============>...............] - ETA: 0s - loss: 0.1795 - bounding_box_loss: 0.0063 - class_label_loss: 0.1732 - bounding_box_accuracy: 0.5625 - class_label_accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.2600s). Check your callbacks.
# 4/4 [==============================] - 3s 740ms/step - loss: 0.2018 - bounding_box_loss: 0.0062 - class_label_loss: 0.1956 - bounding_box_accuracy: 0.5938 - class_label_accuracy: 0.9375 - val_loss: 0.1720 - val_bounding_box_loss: 0.0081 - val_class_label_loss: 0.1640 - val_bounding_box_accuracy: 0.8889 - val_class_label_accuracy: 1.0000
# Epoch 2/50
# 4/4 [==============================] - 1s 344ms/step - loss: 0.1262 - bounding_box_loss: 0.0047 - class_label_loss: 0.1215 - bounding_box_accuracy: 0.8438 - class_label_accuracy: 0.9688 - val_loss: 0.1457 - val_bounding_box_loss: 0.0078 - val_class_label_loss: 0.1380 - val_bounding_box_accuracy: 0.6667 - val_class_label_accuracy: 1.0000
# Epoch 3/50
# 4/4 [==============================] - 1s 355ms/step - loss: 0.0694 - bounding_box_loss: 0.0036 - class_label_loss: 0.0658 - bounding_box_accuracy: 0.8125 - class_label_accuracy: 1.0000 - val_loss: 0.1265 - val_bounding_box_loss: 0.0071 - val_class_label_loss: 0.1194 - val_bounding_box_accuracy: 0.6667 - val_class_label_accuracy: 1.0000
# Epoch 4/50
# 4/4 [==============================] - 1s 350ms/step - loss: 0.1246 - bounding_box_loss: 0.0026 - class_label_loss: 0.1220 - bounding_box_accuracy: 0.8438 - class_label_accuracy: 0.9688 - val_loss: 0.1173 - val_bounding_box_loss: 0.0061 - val_class_label_loss: 0.1112 - val_bounding_box_accuracy: 0.7778 - val_class_label_accuracy: 1.0000
# Epoch 5/50
# 4/4 [==============================] - 1s 343ms/step - loss: 0.
- bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0224 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0178 - val_bounding_box_accuracy: 0.8889 - val_class_label_accuracy: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0065 - bounding_box_loss: 1.0013e-04 - class_label_loss: 0.0064 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0215 - val_bounding_box_loss: 0.0049 - val_class_label_loss: 0.0166 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 1s 350ms/step - loss: 0.0022 - bounding_box_loss: 9.6272e-05 - class_label_loss: 0.0021 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0209 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0162 - val_bounding_box_accuracy: 0.8889 - val_class_label_accuracy: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0020 - bounding_box_loss: 8.8246e-05 - class_label_loss: 0.0019 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0208 - val_bounding_box_loss: 0.0049 - val_class_label_loss: 0.0159 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 32/50
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0084 - bounding_box_loss: 8.5651e-05 - class_label_loss: 0.0083 - bounding_box_accuracy: 0.9375 - class_label_accuracy: 1.0000 - val_loss: 0.0188 - val_bounding_box_loss: 0.0046 - val_class_label_loss: 0.0142 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 1s 355ms/step - loss: 0.0058 - bounding_box_loss: 7.8831e-05 - class_label_loss: 0.0057 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0179 - val_bounding_box_loss: 0.0049 - val_class_label_loss: 0.0130 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 1s 358ms/step - loss: 0.0031 - bounding_box_loss: 7.3965e-05 - class_label_loss: 0.0030 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0172 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0125 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0081 - bounding_box_loss: 6.9668e-05 - class_label_loss: 0.0081 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0172 - val_bounding_box_loss: 0.0049 - val_class_label_loss: 0.0124 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0048 - bounding_box_loss: 6.6567e-05 - class_label_loss: 0.0048 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0177 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0130 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0117 - bounding_box_loss: 6.6099e-05 - class_label_loss: 0.0117 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0209 - val_bounding_box_loss: 0.0049 - val_class_label_loss: 0.0160 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0036 - bounding_box_loss: 5.8786e-05 - class_label_loss: 0.0035 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0252 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0204 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0034 - bounding_box_loss: 6.2655e-05 - class_label_loss: 0.0033 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0301 - val_bounding_box_loss: 0.0048 - val_class_label_loss: 0.0252 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0066 - bounding_box_loss: 6.1140e-05 - class_label_loss: 0.0065 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0318 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0271 - val_bounding_box_accuracy: 0.8889 - val_class_label_accuracy: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 1s 340ms/step - loss: 0.0123 - bounding_box_loss: 5.6370e-05 - class_label_loss: 0.0122 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0449 - val_bounding_box_loss: 0.0048 - val_class_label_loss: 0.0401 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0049 - bounding_box_loss: 6.2056e-05 - class_label_loss: 0.0049 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0469 - val_bounding_box_loss: 0.0049 - val_class_label_loss: 0.0420 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0079 - bounding_box_loss: 5.2815e-05 - class_label_loss: 0.0079 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0410 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0363 - val_bounding_box_accuracy: 0.8889 - val_class_label_accuracy: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0061 - bounding_box_loss: 5.6663e-05 - class_label_loss: 0.0060 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0321 - val_bounding_box_loss: 0.0050 - val_class_label_loss: 0.0271 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0232 - bounding_box_loss: 6.7283e-05 - class_label_loss: 0.0231 - bounding_box_accuracy: 0.9375 - class_label_accuracy: 1.0000 - val_loss: 0.0207 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0161 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0043 - bounding_box_loss: 5.1397e-05 - class_label_loss: 0.0042 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0236 - val_bounding_box_loss: 0.0048 - val_class_label_loss: 0.0188 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0021 - bounding_box_loss: 4.7681e-05 - class_label_loss: 0.0021 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0264 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0217 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0055 - bounding_box_loss: 4.3769e-05 - class_label_loss: 0.0055 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0253 - val_bounding_box_loss: 0.0048 - val_class_label_loss: 0.0205 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0025 - bounding_box_loss: 3.9818e-05 - class_label_loss: 0.0024 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0225 - val_bounding_box_loss: 0.0048 - val_class_label_loss: 0.0177 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0029 - bounding_box_loss: 3.7646e-05 - class_label_loss: 0.0028 - bounding_box_accuracy: 0.9688 - class_label_accuracy: 1.0000 - val_loss: 0.0184 - val_bounding_box_loss: 0.0047 - val_class_label_loss: 0.0136 - val_bounding_box_accuracy: 1.0000 - val_class_label_accuracy: 1.0000

# %%
model.save('3.h5', save_format="h5")
with open('lb3.pickle', "wb") as f:
    f.write(pickle.dumps(lb))

# %%
# plot the total loss, label loss, and bounding box loss
lossNames = ["loss", "class_label_loss", "bounding_box_loss"]
N = np.arange(0, H.params['epochs'])
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))

# loop over the loss names
for (i, l) in enumerate(lossNames):
    # plot the loss for both the training and validation data
    title = "Loss for {}".format(l) if l != "loss" else "Total loss"
    ax[i].set_title(title)
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Loss")
    ax[i].plot(N, H.history[l], label=l)
    ax[i].plot(N, H.history["val_" + l], label="val_" + l)
    ax[i].legend()

# save the losses figure and create a new figure for the accuracies
plt.tight_layout()

# create a new figure for the accuracies
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["class_label_accuracy"], label="class_label_train_acc")
plt.plot(N, H.history["val_class_label_accuracy"], label="val_class_label_acc")
plt.title("Class Label Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
